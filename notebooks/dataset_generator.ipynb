# %%
# Import the os module to interact with the operating system environment variables
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
file_path = "heartstart RAG.pdf"
loader = PyPDFLoader(file_path)

docs = loader.load()

print(len(docs))
# Out:
# 300

# %%
print(docs[0].page_content)
print(docs[0].metadata)
# Out:
# Instructions for Use
# HeartStart Intrepid
# Monitor /D efibrillator
# 867172
#  English
#
# {'source': 'heartstart RAG.pdf', 'page': 0}

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(docs)

# %%
from huggingface_hub import InferenceClient
import json

repo_id = "mistralai/Mixtral-8x7B-Instruct-v0.1"

llm_client = InferenceClient(
    model=repo_id,
    timeout=120,
    api_key=os.getenv('HUGGING_FACE_API_TOKEN')
)


def call_llm(inference_client: InferenceClient, prompt: str):
    response = inference_client.post(
        json={
            "inputs": prompt,
            "parameters": {"max_new_tokens": 1000},
            "task": "text-generation",
        },
    )
    return json.loads(response.decode())[0]["generated_text"]

# %%
QA_generation_prompt = """
Your task is to write a factoid question and an answer given a context.
Your factoid question should be answerable with a specific, concise piece of factual information from the context.
Your factoid question should be formulated in the same style as questions users could ask in a search engine.
Provide one relevant question and answer for the given context

Provide your answer as follows:

Output:::
Factoid question: (your factoid question)
Answer: (your answer to the factoid question)

Now here is the context.

Context: {context}\n
Output:::"""

# %%
import random
from tqdm.auto import tqdm
import pandas as pd
N_GENERATIONS = 10  # We intentionally generate only 10 QA couples here for cost and time considerations

print(f"Generating {N_GENERATIONS} QA couples...")

outputs = []
for sampled_context in tqdm(random.sample(splits, N_GENERATIONS)):
    # Generate QA couple
    output_QA_couple = call_llm(llm_client, QA_generation_prompt.format(context=sampled_context.page_content))
    try:
        #print(output_QA_couple)
        keyword ="Factoid question: (your factoid question)"
        before_keyword, keyword, after_keyword = output_QA_couple.partition(keyword)
        #print(after_keyword)
        actual_keyword = "Factoid question:"
        before_actual_question,actual_keyword,after_actual_keyword = after_keyword.partition(actual_keyword)
        #print("actual_question", after_actual_keyword)
        question = output_QA_couple.split("Factoid question: ")[-1].split("Answer: ")[0]
        answer = output_QA_couple.split("Answer: ")[-1]
        assert len(answer) < 300, "Answer is too long"
        print(sampled_context.metadata)
        outputs.append(
            {
                "context": sampled_context.page_content,
                "question": question,
                "answer": answer,
                "source_doc": sampled_context.metadata["source"],
                "page_no":sampled_context.metadata["page"]
            }
        )
    except:
        continue
# Out:
# Generating 10 QA couples...
#   0%|          | 0/10 [00:00<?, ?it/s]
# C:\Users\Hrisi\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# {'source': 'heartstart RAG.pdf', 'page': 236}
# {'source': 'heartstart RAG.pdf', 'page': 82}
# {'source': 'heartstart RAG.pdf', 'page': 274}
# {'source': 'heartstart RAG.pdf', 'page': 236}
# {'source': 'heartstart RAG.pdf', 'page': 168}
# {'source': 'heartstart RAG.pdf', 'page': 131}
# {'source': 'heartstart RAG.pdf', 'page': 284}
# {'source': 'heartstart RAG.pdf', 'page': 180}
# {'source': 'heartstart RAG.pdf', 'page': 192}
# {'source': 'heartstart RAG.pdf', 'page': 251}

# %%
display(pd.DataFrame(outputs))
# Out:
#                                              context  \
# 0   Q-CPR meter 2 Accessories        .      .   ...
# 1  chest hair, moisture and lotions or powders on...
# 2  Info” and selecting ‘yes’. This action will re...
# 3  223\n18\nSupplies and Accessories\nThis chapte...
# 4  (if configured) that no compressions are detec...
# 5  9: Monitoring Noninvasive Blood Pressure and T...
# 6  Electromagnetic Compatibility 20: Specificatio...
# 7  Daylight Saving Time (DST) changes occur when ...
# 8  Configurable Parameters 14: Configuration\n 17...
# 9  some wires in a 5-Lead cable \nare disconnecte...
#
#                                             question  \
# 0  What are some accessories for the Q-CPR meter ...
# 1  What is the purpose of the AED mode-related in...
# 2  What standard does the HeartStart Intrepid mee...
# 3  What type of accessories are discussed in this...
# 4  What is the target area for the compression ra...
# 5  How do you disable temperature alarms on the m...
# 6  What is the limit level for the radiated RF el...
# 7   What is the time format setting on the device?\n
# 8  What are the EAP types available for WPA_AES_P...
# 9  What could be the reason for a technical alarm...
#
#                                               answer          source_doc  \
# 0  Some accessories for the Q-CPR meter 2 include...  heartstart RAG.pdf
# 1  The AED mode-related information in the AED Vi...  heartstart RAG.pdf
# 2  The HeartStart Intrepid meets the IEC 60601-2-...  heartstart RAG.pdf
# 3  This chapter discusses approved supplies and a...  heartstart RAG.pdf
# 4  The target area for the compression rate indic...  heartstart RAG.pdf
# 5  To disable temperature alarms on the monitor, ...  heartstart RAG.pdf
# 6  The limit level for the radiated RF electromag...  heartstart RAG.pdf
# 7  The time format setting on the device is defin...  heartstart RAG.pdf
# 8  The EAP types available for WPA_AES_PSK are PE...  heartstart RAG.pdf
# 9  An electrode may be disconnected or the analyz...  heartstart RAG.pdf
#
#    page_no
# 0      236
# 1       82
# 2      274
# 3      236
# 4      168
# 5      131
# 6      284
# 7      180
# 8      192
# 9      251

# %%
qa_dataset = pd.DataFrame(outputs)
qa_dataset.to_csv("qa_dataset.csv")

# %%
question_groundedness_critique_prompt = """
You will be given a context and a question.
Your task is to provide a 'total rating' scoring how well one can answer the given question unambiguously with the given context.
Give your answer on a scale of 1 to 5, where 1 means that the question is not answerable at all given the context, and 5 means that the question is clearly and unambiguously answerable with the context.

Provide your answer as follows:

Answer:::
Evaluation: (your rationale for the rating, as a text)
Total rating: (your rating, as a number between 1 and 5)

You MUST provide values for 'Evaluation:' and 'Total rating:' in your answer.

Now here are the question and context.

Question: {question}\n
Context: {context}\n
Answer::: """

question_relevance_critique_prompt = """
You will be given a question.
Your task is to provide a 'total rating' representing how useful this question can be to users using the "Philips Heart Start Intrepid Monitor"
Give your answer on a scale of 1 to 5, where 1 means that the question is not useful at all, and 5 means that the question is extremely useful.

Provide your answer as follows:

Answer:::
Evaluation: (your rationale for the rating, as a text)
Total rating: (your rating, as a number between 1 and 5)

You MUST provide values for 'Evaluation:' and 'Total rating:' in your answer.

Now here is the question.

Question: {question}\n
Answer::: """

question_standalone_critique_prompt = """
You will be given a question.
Your task is to provide a 'total rating' representing how context-independent this question is.
Give your answer on a scale of 1 to 5, where 1 means that the question depends on additional information to be understood, and 5 means that the question makes sense by itself.
For instance, if the question refers to a particular setting, like 'in the context' or 'in the document', the rating must be 1.

Provide your answer as follows:

Answer:::
Evaluation: (your rationale for the rating, as a text)
Total rating: (your rating, as a number between 1 and 5)

You MUST provide values for 'Evaluation:' and 'Total rating:' in your answer.

Now here is the question.

Question: {question}\n
Answer::: """

# %%
print("Generating critique for each QA couple...")
for output in tqdm(outputs):
    evaluations = {
        "groundedness": call_llm(
            llm_client,
            question_groundedness_critique_prompt.format(context=output["context"], question=output["question"]),
        ),
        "relevance": call_llm(
            llm_client,
            question_relevance_critique_prompt.format(question=output["question"]),
        ),
        "standalone": call_llm(
            llm_client,
            question_standalone_critique_prompt.format(question=output["question"]),
        ),
    }
    try:
        for criterion, evaluation in evaluations.items():
            score, eval = (
                int(evaluation.split("Total rating: ")[-1].strip()),
                evaluation.split("Total rating: ")[-2].split("Evaluation: ")[1],
            )
            output.update(
                {
                    f"{criterion}_score": score,
                    f"{criterion}_eval": eval,
                }
            )
    except Exception as e:
        continue
# Out:
# Generating critique for each QA couple...
#   0%|          | 0/10 [00:00<?, ?it/s]
# C:\Users\Hrisi\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)

# %%
display(pd.DataFrame(outputs))
# Out:
#                                              context  \
# 0   Q-CPR meter 2 Accessories        .      .   ...
# 1  chest hair, moisture and lotions or powders on...
# 2  Info” and selecting ‘yes’. This action will re...
# 3  223\n18\nSupplies and Accessories\nThis chapte...
# 4  (if configured) that no compressions are detec...
# 5  9: Monitoring Noninvasive Blood Pressure and T...
# 6  Electromagnetic Compatibility 20: Specificatio...
# 7  Daylight Saving Time (DST) changes occur when ...
# 8  Configurable Parameters 14: Configuration\n 17...
# 9  some wires in a 5-Lead cable \nare disconnecte...
#
#                                             question  \
# 0  What are some accessories for the Q-CPR meter ...
# 1  What is the purpose of the AED mode-related in...
# 2  What standard does the HeartStart Intrepid mee...
# 3  What type of accessories are discussed in this...
# 4  What is the target area for the compression ra...
# 5  How do you disable temperature alarms on the m...
# 6  What is the limit level for the radiated RF el...
# 7   What is the time format setting on the device?\n
# 8  What are the EAP types available for WPA_AES_P...
# 9  What could be the reason for a technical alarm...
#
#                                               answer          source_doc  \
# 0  Some accessories for the Q-CPR meter 2 include...  heartstart RAG.pdf
# 1  The AED mode-related information in the AED Vi...  heartstart RAG.pdf
# 2  The HeartStart Intrepid meets the IEC 60601-2-...  heartstart RAG.pdf
# 3  This chapter discusses approved supplies and a...  heartstart RAG.pdf
# 4  The target area for the compression rate indic...  heartstart RAG.pdf
# 5  To disable temperature alarms on the monitor, ...  heartstart RAG.pdf
# 6  The limit level for the radiated RF electromag...  heartstart RAG.pdf
# 7  The time format setting on the device is defin...  heartstart RAG.pdf
# 8  The EAP types available for WPA_AES_PSK are PE...  heartstart RAG.pdf
# 9  An electrode may be disconnected or the analyz...  heartstart RAG.pdf
#
#    page_no  groundedness_score  \
# 0      236                   5
# 1       82                   5
# 2      274                   5
# 3      236                   5
# 4      168                   5
# 5      131                   5
# 6      284                   5
# 7      180                   1
# 8      192                   1
# 9      251                   5
#
#                                    groundedness_eval  relevance_score  \
# 0  The context lists several items under the head...              4.0
# 1  The context provides a description of the AED ...              5.0
# 2  The context clearly states that the HeartStart...              4.0
# 3  The context lists three sections under the hea...              2.0
# 4  The context provides a clear description of th...              4.0
# 5  The context provides a clear and unambiguous a...              4.0
# 6  The context provides the limit level for the r...              4.0
# 7  The context provides information about the con...              4.0
# 8  The context provides information about the EAP...              NaN
# 9  The context provides several possible reasons ...              5.0
#
#                                       relevance_eval  standalone_score  \
# 0  This question is useful for users who want to ...               5.0
# 1  This question is useful for users of the Phili...               3.0
# 2  This question is useful for those who are inte...               2.0
# 3  This question is related to the content of the...               2.0
# 4  This question is useful for users of the Phili...               2.0
# 5  This question is useful for users who want to ...               4.0
# 6  This question is useful for those who are conc...               5.0
# 7  This question is useful for users who want to ...               4.0
# 8                                                NaN               NaN
# 9  This question is useful for users of the Phili...               2.0
#
#                                      standalone_eval
# 0  This question is context-independent as it ref...
# 1  This question assumes knowledge of an 'AED Vie...
# 2  This question is context-dependent because it ...
# 3  This question is context-dependent, as it refe...
# 4  This question is context-dependent because it ...
# 5  This question is context-independent, as it re...
# 6  This question is asking about the limit level ...
# 7  This question is context-independent because i...
# 8                                                NaN
# 9  This question is context-dependent because it ...

# %%
import pandas as pd

pd.set_option("display.max_colwidth", None)

generated_questions = pd.DataFrame.from_dict(outputs)

print("Evaluation dataset before filtering:")
display(
    generated_questions[
        [
            "question",
            "answer",
            "groundedness_score",
            "relevance_score",
            "standalone_score",
        ]
    ]
)
generated_questions = generated_questions.loc[
    (generated_questions["groundedness_score"] >= 4)
    & (generated_questions["relevance_score"] >= 4)
    & (generated_questions["standalone_score"] >= 4)
]
print("============================================")
print("Final evaluation dataset:")
display(
    generated_questions[
        [
            "question",
            "answer",
            "groundedness_score",
            "relevance_score",
            "standalone_score",
        ]
    ]
)
# Out:
# Evaluation dataset before filtering:
#                                                                                                                                question  \
# 0                                                                                    What are some accessories for the Q-CPR meter 2?\n
# 1                                                            What is the purpose of the AED mode-related information in the AED View?\n
# 2                                                         What standard does the HeartStart Intrepid meet in terms of safety and EMC?\n
# 3                                                                             What type of accessories are discussed in this chapter?\n
# 4                                                    What is the target area for the compression rate indicator on the Q-CPR meter 2?\n
# 5                                                                               How do you disable temperature alarms on the monitor?\n
# 6  What is the limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply?\n
# 7                                                                                      What is the time format setting on the device?\n
# 8                                                                                   What are the EAP types available for WPA_AES_PSK?\n
# 9                                                                     What could be the reason for a technical alarm in the ECG data?\n
#
#                                                                                                                                                                               answer  \
# 0                                Some accessories for the Q-CPR meter 2 include SpO2 cables and sensors, temperature monitoring probes and cables, and test loads and shorted plugs.
# 1            The AED mode-related information in the AED View displays important messages for the user and the configured energy for the current patient category while in AED mode.
# 2                                                                              The HeartStart Intrepid meets the IEC 60601-2-30 ed. 1.1 and (EN) ISO 80601 safety and EMC standards.
# 3                  This chapter discusses approved supplies and accessories, ECG and defibrillation accessories, and blood pressure air hoses and cuffs for the HeartStart Intrepid.
# 4                                                        The target area for the compression rate indicator on the Q-CPR meter 2 is the green target zone on the speedometer needle.
# 5                                                                           To disable temperature alarms on the monitor, press the Smart Select knob. The alarms are on by default.
# 6  The limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply is 20 V/m for the frequency range of 80 MHz to 2.7 GHz.
# 7          The time format setting on the device is defined by the Time Format parameter in the Date/Time Format configuration. The available choices are 12-hour or 24-hour format.
# 8                                                                                                    The EAP types available for WPA_AES_PSK are PEAP-MSCHAP, EAP-TTLS, and EAP-TLS.
# 9                                                                                         An electrode may be disconnected or the analyzing algorithm cannot analyze the ECG signal.
#
#    groundedness_score  relevance_score  standalone_score
# 0                   5              4.0               5.0
# 1                   5              5.0               3.0
# 2                   5              4.0               2.0
# 3                   5              2.0               2.0
# 4                   5              4.0               2.0
# 5                   5              4.0               4.0
# 6                   5              4.0               5.0
# 7                   1              4.0               4.0
# 8                   1              NaN               NaN
# 9                   5              5.0               2.0
# ============================================
# Final evaluation dataset:
#                                                                                                                                question  \
# 0                                                                                    What are some accessories for the Q-CPR meter 2?\n
# 5                                                                               How do you disable temperature alarms on the monitor?\n
# 6  What is the limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply?\n
#
#                                                                                                                                                                               answer  \
# 0                                Some accessories for the Q-CPR meter 2 include SpO2 cables and sensors, temperature monitoring probes and cables, and test loads and shorted plugs.
# 5                                                                           To disable temperature alarms on the monitor, press the Smart Select knob. The alarms are on by default.
# 6  The limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply is 20 V/m for the frequency range of 80 MHz to 2.7 GHz.
#
#    groundedness_score  relevance_score  standalone_score
# 0                   5              4.0               5.0
# 5                   5              4.0               4.0
# 6                   5              4.0               5.0

# %%
eval_dataset = pd.DataFrame(generated_questions)
eval_dataset
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        context  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Q-CPR meter 2 Accessories        .      .      .      .      .      .      .      .      .      .      .      .      .       p. 229\n SpO2 Cables and Sensors     .      .      .      .      .      .      .      .      .      .      .      .      .      .       p. 230\n Temperature Monitoring Probes and Cables     .      .      .      .      .      .      .      .      .      .       p. 230\n Test Loads and Shorted Plugs      .      .      .      .      .      .      .      .      .      .      .      .      .       p. 231
# 5                                                                                      9: Monitoring Noninvasive Blood Pressure and Temperature Monitoring T emperature\n118\n NOTE: Alarm notification is configurable. See “Alarm Management and Configuration” on page 42.\nIf alarms are enabled, alarm limits appear next to the value. If alarms are off, the Alarms Off  \nsymbol replaces the limits. \nChanging Temperature Alarm Limits\n T o change the temperature alarm limits for the current incident:\n1 Press the Smart Select knob.\n2 T urn the Smart Select knob to highlight  and press the Smart Select \nknob. \n3 Select and press the Smart Select knob. \n4 Select  and press the Smart Select knob.\n5 T urn the Smart Select knob to change the high limit and press the Smart Select knob. \n6 T urn the Smart Select knob to change the low limit and press the Smart Select knob. \nEnabling/Disabling Temperature Alarms\n T o disable temperature alarms (the alarms are on by default):\n1 Press the Smart Select knob.
# 6  Electromagnetic Compatibility 20: Specifications and Safety\n 271\nThe emission of the HeartStart Intrepid can meet Class I limit level of CISPR 25 when powered by \na DC-DC power supply.\nRadiated RF \nElectromagnetic \nField\nIEC 60601-2-4 \n(see Para. \n202.6.2.3)\n20 V/m (only \ndefibrillation)\n80 MHz to 2.7 GHz\n20 V/m (only \ndefibrillation)\n80 MHz to 2.7 GHz\nEmergency medical services \nenvironment\nProfessional healthcare facility \nenvironment\nProximity fields \nfrom RF wireless \ncommunications \nequipment\nIEC 61000-4-3\nRefer to table 126 \nbelow\nRefer to table 126 below Emergency medical services \nenvironment\nProfessional healthcare facility \nenvironment\nPower frequency \nmagnetic field\nIEC 61000-4-8\n30 A/m\n50 Hz or 60 Hz\n30 A/m\n50 Hz or 60 Hz\nEmergency medical services \nenvironment\nProfessional healthcare facility \nenvironment\nTable 126 Proximity Fields from RF Wireless Communications Equipment \nT est \nFrequency \n(MHz)\nBand a) \n(MHz)\nService a) Modulation \nb)\nModulation \nb) \n(W)\nDistance\n(m)
#
#                                                                                                                                question  \
# 0                                                                                    What are some accessories for the Q-CPR meter 2?\n
# 5                                                                               How do you disable temperature alarms on the monitor?\n
# 6  What is the limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply?\n
#
#                                                                                                                                                                               answer  \
# 0                                Some accessories for the Q-CPR meter 2 include SpO2 cables and sensors, temperature monitoring probes and cables, and test loads and shorted plugs.
# 5                                                                           To disable temperature alarms on the monitor, press the Smart Select knob. The alarms are on by default.
# 6  The limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply is 20 V/m for the frequency range of 80 MHz to 2.7 GHz.
#
#            source_doc  page_no  groundedness_score  \
# 0  heartstart RAG.pdf      236                   5
# 5  heartstart RAG.pdf      131                   5
# 6  heartstart RAG.pdf      284                   5
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                groundedness_eval  \
# 0                                                                                                                                                                                                                                                                                                                                                   The context lists several items under the heading "Q-CPR meter 2 Accessories," providing a clear and unambiguous answer to the question.\n\n
# 5                                                                                                                                                                                                                                                                                                                                   The context provides a clear and unambiguous answer to the question, with step-by-step instructions on how to disable temperature alarms on the monitor.\n\n
# 6  The context provides the limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply, which is 20 V/m for the frequency range of 80 MHz to 2.7 GHz. The context also specifies that the emission of the HeartStart Intrepid can meet Class I limit level of CISPR 25 when powered by a DC-DC power supply, which further supports the answer. Therefore, the question is clearly and unambiguously answerable with the context.\n\n
#
#    relevance_score  \
# 0              4.0
# 5              4.0
# 6              4.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                    relevance_eval  \
# 0                                                                                                                                                                                                                                                                                                     This question is useful for users who want to know more about the accessories for the Q-CPR meter 2. It can help them to use the device more effectively and efficiently.\n
# 5                                                                                                                                                       This question is useful for users who want to customize the settings of their Philips Heart Start Intrepid Monitor, specifically to disable temperature alarms. Disabling alarms can be important for ensuring that the monitor is not providing unnecessary alerts, which can be distracting or confusing for users.\n\n
# 6  This question is useful for those who are concerned about the electromagnetic compatibility of the HeartStart Intrepid when using a DC-DC power supply. The limit level for the radiated RF electromagnetic field is an important safety consideration, as it ensures that the device does not interfere with other medical equipment or devices in the vicinity. Knowing the limit level can also help in the proper installation and operation of the HeartStart Intrepid.\n
#
#    standalone_score  \
# 0               5.0
# 5               4.0
# 6               5.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                              standalone_eval
# 0                                                                                                                                                                                                                                                                                             This question is context-independent as it refers to a specific product, the Q-CPR meter 2, and asks for accessories for it.\n
# 5                                                                                                                     This question is context-independent, as it refers to a general action that can be performed on any monitor with temperature alarms. However, it does not specify the type of monitor or the brand, which could lead to confusion if the user is not familiar with the specific monitor in question.\n
# 6  This question is asking about the limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply. It is clear what the question is asking, and it does not depend on any additional context. The question refers to a specific product, the HeartStart Intrepid, and a specific power source, a DC-DC power supply, but it is still clear what is being asked.\n\n

# %% [markdown]
# # RAG Setup

# %%
from langchain.embeddings import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings()
# Out:
# C:\Users\Hrisi\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
from langchain_pinecone import PineconeVectorStore
INDEX_NAME = "chatbotqa-index"
docsearch = PineconeVectorStore(index_name=INDEX_NAME, embedding=embeddings)

# %%
retriver = docsearch.as_retriever(search_kwargs={"k": 3})

# %%
from langchain.llms import HuggingFaceHub
import os
# Define the repo ID and connect to Mixtral model on Huggingface
repo_id = "mistralai/Mixtral-8x7B-Instruct-v0.1"
llm_rag = HuggingFaceHub(
  repo_id=repo_id, 
  model_kwargs={"temperature": 0.8, "top_k": 50}, 
  huggingfacehub_api_token=os.getenv('HUGGING_FACE_API_TOKEN')
)

# %%
from langchain import PromptTemplate

template = """Use the following pieces of context to answer the question. Please follow the following rules:
1. Only share the final answer in the "result".
2. If you don't know the answer, don't try to make up an answer. Just say "I can't find the final answer but you may want to check the following links".
3. If you find the answer, write the answer in a concise way with five sentences maximum.

{context}

Question: {question}

Helpful Answer:
"""

prompt = PromptTemplate(
  template=template, 
  input_variables=["context", "question"]
)

# %%
from langchain.chains import ConversationalRetrievalChain, RetrievalQA
rag_chain = RetrievalQA.from_chain_type(
            llm_rag, retriever=docsearch.as_retriever(), chain_type_kwargs={"prompt": prompt}
        )

# %%
final_outputs = []
for idx,row in eval_dataset.iterrows():
    question = row["question"]
    print(question)
    response_rag = rag_chain.invoke(question)
    print(response_rag)
    keyword = "Helpful Answer:"
    before_keyword, keyword, after_keyword = response_rag['result'].partition(keyword)

    result = {
            "question": question,
            "true_answer": row["answer"],
            "source_page": row["page_no"],
            "generated_answer": after_keyword
        }
    final_outputs.append(result)
# Out:
# What are some accessories for the Q-CPR meter 2?
# C:\Users\Hrisi\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# {'query': 'What are some accessories for the Q-CPR meter 2?\n', 'result': 'Use the following pieces of context to answer the question. Please follow the following rules:\n1. Only share the final answer in the "result".\n2. If you don\'t know the answer, don\'t try to make up an answer. Just say "I can\'t find the final answer but you may want to check the following links".\n3. If you find the answer, write the answer in a concise way with five sentences maximum.\n\nPaper  .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      . 229\nPower Supply Accessories.      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      . 229\nQ-CPR meter 2 Accessories   .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      . 229\nSpO2 Cables and Sensors .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      . 230\nT emperature Monitoring Probes and Cables .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      . 230\n\nPaper 18: Supplies and Accessories\n 229\nPaper \nTable 100 Paper\nPower Supply Accessories\nTable 101 Power Supply Accessories\nQ-CPR meter 2 Accessories\nM3718A Adult/child radiotransparent multifunction electrode pads, 10 sets/case\nM3719A Infant radiotransparent multifunction electrode pads, 5 sets/case\n989803139261 SMART Pads II for adults, children, and infants, 1 set\n989803149981 SMART Pads III for adults, children, and infants, 1 set\n989803149991 SMART Pads III for adults, children, and infants, 5 sets\n989803158211 HeartStart adult multifunction electrode pads, 1 set\n989803158221 HeartStart adult multifunction electrode pads, 5 sets\n989803166021 Adult/child preconnect multifunction electrode pads, 10 sets\nTable 99 Multifunction Electrode Pads  (Continued)\nPart Number Description\nPart Number Description \n989803138171 75 mm chemical thermal paper, 10 rolls\nPart Number Description \n989803202601 Rechargeable lithium ion battery pack\n(discontinued upon 989803206451 release)\n\nHeartStart Intrepid Disposal     .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .    222\nQ-CPR meter 2 and Adhesive Pad Disposal     .      .      .      .      .      .      .      .      .      .      .      .      .      .      .    222\nChapter 18 Supplies and Accessories 223\nApproved Supplies and Accessories .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .    224\nECG and Defibrillation Accessories      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .    224\nBlood Pressure Air Hoses and Cuffs      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .    224\nCable Management and Accessory Storage .      .      .      .      .      .      .      .      .      .      .      .      .      .      .      .    225\n\n\uf038 Q-CPR meter 2 Accessories        .      .      .      .      .      .      .      .      .      .      .      .      .       p. 229\n\uf038 SpO2 Cables and Sensors     .      .      .      .      .      .      .      .      .      .      .      .      .      .       p. 230\n\uf038 Temperature Monitoring Probes and Cables     .      .      .      .      .      .      .      .      .      .       p. 230\n\uf038 Test Loads and Shorted Plugs      .      .      .      .      .      .      .      .      .      .      .      .      .       p. 231\n\nQuestion: What are some accessories for the Q-CPR meter 2?\n\n\nHelpful Answer:\nThe Q-CPR meter 2 accesso ...
# How do you disable temperature alarms on the monitor?
# C:\Users\Hrisi\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# {'query': 'How do you disable temperature alarms on the monitor?\n', 'result': 'Use the following pieces of context to answer the question. Please follow the following rules:\n1. Only share the final answer in the "result".\n2. If you don\'t know the answer, don\'t try to make up an answer. Just say "I can\'t find the final answer but you may want to check the following links".\n3. If you find the answer, write the answer in a concise way with five sentences maximum.\n\nEnabling/Disabling Temperature Alarms\n\uf0a5 T o disable temperature alarms (the alarms are on by default):\n1 Press the Smart Select knob.\n2 T urn the Smart Select knob to highlight \uf04d\uf065\uf061\uf073\uf075\uf072\uf065\uf06d\uf065\uf06e\uf074\uf073\uf02f\uf041\uf06c\uf061\uf072\uf06d\uf073 and press the Smart Select \nknob.\n3 Select \uf054\uf065\uf06d\uf070.\n4 Select \uf041\uf06c\uf061\uf072\uf06d\uf073\uf020\uf04f\uf06e or \uf041\uf06c\uf061\uf072\uf06d\uf073\uf020\uf04f\uf066\uf066 and press the Smart Select knob. \nTable 25 Temperature Alarms\nAlarm Message Condition Type of Alarm Indicator\n\uf054\uf065\uf06d\uf070\uf020\uf048\uf069\uf067\uf068 The temperature value exceeds \nthe high alarm limit.\nMedium \npriority \nlatching \nconfigurable \nalarm\nYellow alarm message \nwith audio tone \uf054\uf065\uf06d\uf070\uf020\uf04c\uf06f\uf077 The temperature value has fallen \nbelow the low alarm limit.\nT emp out of \nrange\nT emperature out of range Low priority\nCyan alarm message \nwith audio tone \nT emp \nEquipment \nMalfunction\nT emperature Monitoring \nMalfunction\nLow priority\nT emp \nCalibration \nFailed\nT emperature Calibration Failure Low priority\nT emp \nUnplugged\nT emperature probe has become \ndisconnected.\nLow priority\nT emp Error T emperature Source \nMalfunction\nLow priority\n\n9: Monitoring Noninvasive Blood Pressure and Temperature Monitoring T emperature\n118\n NOTE: Alarm notification is configurable. See “Alarm Management and Configuration” on page 42.\nIf alarms are enabled, alarm limits appear next to the value. If alarms are off, the Alarms Off  \nsymbol replaces the limits. \nChanging Temperature Alarm Limits\n\uf0a5 T o change the temperature alarm limits for the current incident:\n1 Press the Smart Select knob.\n2 T urn the Smart Select knob to highlight \uf04d\uf065\uf061\uf073\uf075\uf072\uf065\uf06d\uf065\uf06e\uf074\uf073\uf02f\uf041\uf06c\uf061\uf072\uf06d\uf073 and press the Smart Select \nknob. \n3 Select \uf054\uf065\uf06d\uf070\uf020and press the Smart Select knob. \n4 Select \uf054\uf065\uf06d\uf070\uf020\uf04c\uf069\uf06d\uf069\uf074\uf073 and press the Smart Select knob.\n5 T urn the Smart Select knob to change the high limit and press the Smart Select knob. \n6 T urn the Smart Select knob to change the low limit and press the Smart Select knob. \nEnabling/Disabling Temperature Alarms\n\uf0a5 T o disable temperature alarms (the alarms are on by default):\n1 Press the Smart Select knob.\n\ndisabled, alarms remain off until they are turned back on. The HeartStart Intrepid allows for \nadjusting alarm notifications.\nNBP Calibration \nNBP should be calibrated yearly. To calibrate the NBP module, call for service or refer to the \nHeartStart Intrepid Service Manual.\nMonitoring Temperature\n\uf0a5 To monitor temperature:\n1 Connect the temperature cable to the HeartStart Intrepid.\n2 Check that the current device settings (including alarm settings) are appropriate for the patient.\n3 Connect the temperature probe to the cable.\n4 Apply the temperature probe to the patient.\nTemperature Alarms \nAlarms are annunciated when a measurement for the configured source falls outside the configured \nhigh or low limits. Temperature alarms are non-latching alarms, meaning they are automatically \nremoved when their alarm condition no longer exists. Both the source of the alarm and the limits \nmay be changed during an ongoing patient event. There are both audio and visual alerts. For more\n\nMonitoring T emperature 9: ...
# What is the limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply?
# C:\Users\Hrisi\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# {'query': 'What is the limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply?\n', 'result': 'Use the following pieces of context to answer the question. Please follow the following rules:\n1. Only share the final answer in the "result".\n2. If you don\'t know the answer, don\'t try to make up an answer. Just say "I can\'t find the final answer but you may want to check the following links".\n3. If you find the answer, write the answer in a concise way with five sentences maximum.\n\nElectromagnetic Compatibility 20: Specifications and Safety\n 271\nThe emission of the HeartStart Intrepid can meet Class I limit level of CISPR 25 when powered by \na DC-DC power supply.\nRadiated RF \nElectromagnetic \nField\nIEC 60601-2-4 \n(see Para. \n202.6.2.3)\n20 V/m (only \ndefibrillation)\n80 MHz to 2.7 GHz\n20 V/m (only \ndefibrillation)\n80 MHz to 2.7 GHz\nEmergency medical services \nenvironment\nProfessional healthcare facility \nenvironment\nProximity fields \nfrom RF wireless \ncommunications \nequipment\nIEC 61000-4-3\nRefer to table 126 \nbelow\nRefer to table 126 below Emergency medical services \nenvironment\nProfessional healthcare facility \nenvironment\nPower frequency \nmagnetic field\nIEC 61000-4-8\n30 A/m\n50 Hz or 60 Hz\n30 A/m\n50 Hz or 60 Hz\nEmergency medical services \nenvironment\nProfessional healthcare facility \nenvironment\nTable 126 Proximity Fields from RF Wireless Communications Equipment \nT est \nFrequency \n(MHz)\nBand a) \n(MHz)\nService a) Modulation \nb)\nModulation \nb) \n(W)\nDistance\n(m)\n\nemissions or decreased immunity of the HeartStart Intrepid. \nUsing portable and mobile radio communications equipment can affect the operation of this device. \nKeep all portable and mobile radio communications equipment at a minimum distance of 30 cm \n(12 inches) from any part of the HeartStart Intrepid.\nGuidance and Manufacturer’s Declaration\nThe HeartStart Intrepid is intended for use in the electromagnetic environment specified in the \ntables below. The customer or the user of the HeartStart Intrepid should assure that it is used in such \nan environment.\nTable 124 Electromagnetic Emissions\nEmissions T est Compliance Electromagnetic Environment - Guidance\nRF emissions\nCISPR 11/GB4824 \nGroup 1\nRF emissions \nCISPR 11/GB4824\nClass B • Emergency medical services environment\n• Professional healthcare facility environment.\nHarmonic emissions \nIEC 61000-3-2/GB17625.1\nClass A\nVoltage fluctuations/flicker \nemissions\nIEC 61000-3-3/GB17625.2\nComplies\nTable 125 Enclosure Ports\n\nElectromagnetic Compatibility 20: Specifications and Safety\n 269\nRadio Frequency Radiation Exposure\nThis device complies with the U.S. portable radio frequency (RF) exposure limit set forth for an \nuncontrolled environment and is safe for intended operation as described in this instructions for use.\nRF exposure can be reduced by keeping the device as far as possible from the user\'s body or setting \nthe device to a lower output power if such function is available.\nReducing Electromagnetic Interference\nThe HeartStart Intrepid and associated accessories may be susceptible to interference from other RF \nenergy sources and continuous, repetitive, power line bursts. Examples of other sources of RF \ninterference are medical devices, cellular products, information technology equipment and \nradio/television transmission. Should interference be encountered, as demonstrated by error \nconditions, artifact on the ECG or dramatic variations in parameter measurement values, attempt to\n\nElectromagnetic Compatibility 20: Specifications and Safety\n 267\nElectromagnetic Compatibility\nWhen using the HeartStart Intrepid, electromagnetic compatibility with surrounding devices should \nbe assessed. \nA medical device can either generate or receive electromagnetic disturbances. Testing for \nelectromagnetic compatibility EMC with the appropriate accessories has been pe ...

# %%
final_df = pd.DataFrame(final_outputs)
final_df
# Out:
#                                                                                                                                question  \
# 0                                                                                    What are some accessories for the Q-CPR meter 2?\n
# 1                                                                               How do you disable temperature alarms on the monitor?\n
# 2  What is the limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply?\n
#
#                                                                                                                                                                          true_answer  \
# 0                                Some accessories for the Q-CPR meter 2 include SpO2 cables and sensors, temperature monitoring probes and cables, and test loads and shorted plugs.
# 1                                                                           To disable temperature alarms on the monitor, press the Smart Select knob. The alarms are on by default.
# 2  The limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply is 20 V/m for the frequency range of 80 MHz to 2.7 GHz.
#
#    source_page  \
# 0          236
# 1          131
# 2          284
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 generated_answer
# 0  \nThe Q-CPR meter 2 accessories include M3718A Adult/child radiotransparent multifunction electrode pads (10 sets/case) and M3719A Infant radiotransparent multifunction electrode pads (5 sets/case). Additionally, there are SMART Pads II for adults, children, and infants (1 set), SMART Pads III for adults, children, and infants (1 set and 5 sets), HeartStart adult multifunction electrode pads (1 set and 5 sets), Adult/child preconnect multifunction electrode pads (10 sets).
# 1                                                                                                                                                                                                                    \n\nTo disable temperature alarms on the monitor:\n\n1. Press the Smart Select knob.\n2. Turn the Smart Select knob to highlight  and press the Smart Select knob.\n3. Select .\n4. Select  or  and press the Smart Select knob.
# 2                                                                                                                                                                                                                       \n\nThe limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply is 20 V/m, as stated in the CISPR 25 standard for the frequency range of 80 MHz to 2.7 GHz. This limit applies only during defibrillation.

# %%
EVALUATION_PROMPT = """###Task Description:
An instruction (might include an Input inside it), a response to evaluate, a reference answer that gets a score of 5, and a score rubric representing a evaluation criteria are given.
1. Write a detailed feedback that assess the quality of the response strictly based on the given score rubric, not evaluating in general.
2. After writing a feedback, write a score that is an integer between 1 and 5. You should refer to the score rubric.
3. The output format should look as follows: \"Feedback: {{write a feedback for criteria}} [RESULT] {{an integer number between 1 and 5}}\"
4. Please do not generate any other opening, closing, and explanations. Be sure to include [RESULT] in your output.

###The instruction to evaluate:
{instruction}

###Response to evaluate:
{response}

###Reference Answer (Score 5):
{reference_answer}

###Score Rubrics:
[Is the response correct, accurate, and factual based on the reference answer?]
Score 1: The response is completely incorrect, inaccurate, and/or not factual.
Score 2: The response is mostly incorrect, inaccurate, and/or not factual.
Score 3: The response is somewhat correct, accurate, and/or factual.
Score 4: The response is mostly correct, accurate, and factual.
Score 5: The response is completely correct, accurate, and factual.

###Feedback:"""

from langchain.prompts.chat import (
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain.schema import SystemMessage


evaluation_prompt_template = ChatPromptTemplate.from_messages(
    [
        SystemMessage(content="You are a fair evaluator language model."),
        HumanMessagePromptTemplate.from_template(EVALUATION_PROMPT),
    ]
)

# %%
from langchain.chat_models import ChatOpenAI

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

eval_chat_model = ChatOpenAI(model="gpt-4-1106-preview", temperature=0, openai_api_key=OPENAI_API_KEY)
evaluator_name = "GPT4"

# %%
final_eval_result = []
for idx,row in final_df.iterrows():
    eval_prompt = evaluation_prompt_template.format_messages(
            instruction=row["question"],
            response=row["generated_answer"],
            reference_answer=row["true_answer"],
        )
    eval_result = eval_chat_model.invoke(eval_prompt)
    feedback, score = [item.strip() for item in eval_result.content.split("[RESULT]")]
    result = {
            "question": row["question"],
            "true_answer": row["true_answer"], 
            "generated_answer": row["generated_answer"],
            "score": score,
            "feedback": feedback
        }
    final_eval_result.append(result)

# %%
final_eval_result
# Out:
# [{'question': 'What are some accessories for the Q-CPR meter 2?\n',
#   'true_answer': 'Some accessories for the Q-CPR meter 2 include SpO2 cables and sensors, temperature monitoring probes and cables, and test loads and shorted plugs.',
#   'generated_answer': '\nThe Q-CPR meter 2 accessories include M3718A Adult/child radiotransparent multifunction electrode pads (10 sets/case) and M3719A Infant radiotransparent multifunction electrode pads (5 sets/case). Additionally, there are SMART Pads II for adults, children, and infants (1 set), SMART Pads III for adults, children, and infants (1 set and 5 sets), HeartStart adult multifunction electrode pads (1 set and 5 sets), Adult/child preconnect multifunction electrode pads (10 sets).',
#   'score': '3',
#   'feedback': "Feedback: The response lists a variety of electrode pads and SMART Pads that are related to a CPR meter device, which suggests some familiarity with the types of accessories that might be used with such a device. However, the response does not mention any of the specific accessories listed in the reference answer, such as SpO2 cables and sensors, temperature monitoring probes and cables, or test loads and shorted plugs. This indicates that while the response is somewhat related to the topic, it does not accurately or factually match the reference answer's accessories for the Q-CPR meter 2. Therefore, the response is somewhat correct but lacks the specific items that were expected based on the reference answer."},
#  {'question': 'How do you disable temperature alarms on the monitor?\n',
#   'true_answer': 'To disable temperature alarms on the monitor, press the Smart Select knob. The alarms are on by default.',
#   'generated_answer': '\n\nTo disable temperature alarms on the monitor:\n\n1. Press the Smart Select knob.\n2. Turn the Smart Select knob to highlight \uf04d\uf065\uf061\uf073\uf075\uf072\uf065\uf06d\uf065\uf06e\uf074\uf073\uf02f\uf041\uf06c\uf061\uf072\uf06d\uf073 and press the Smart Select knob.\n3. Select \uf054\uf065\uf06d\uf070.\n4. Select \uf041\uf06c\uf061\uf072\uf06d\uf073\uf020\uf04f\uf066\uf066 or \uf041\uf06c\uf061\uf072\uf06d\uf073\uf020\uf04f\uf066\uf066 and press the Smart Select knob.',
#   'score': '4',
#   'feedback': 'Feedback: The response provided is mostly correct and factual. It includes the correct procedure to disable temperature alarms on the monitor by using the Smart Select knob and navigating through the menu to the temperature alarm settings. However, the response includes unnecessary steps and symbols that are not present in the reference answer. The reference answer is more concise and does not mention navigating through menus or selecting specific options like "\uf041\uf06c\uf061\uf072\uf06d\uf073\uf020\uf04f\uf066\uf066." The response could be improved by simplifying the instructions and removing the symbols that may not be clear or necessary for the task.'},
#  {'question': 'What is the limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply?\n',
#   'true_answer': 'The limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply is 20 V/m for the frequency range of 80 MHz to 2.7 GHz.',
#   'generated_answer': '\n\nThe limit level for the radiated RF electromagnetic field of the HeartStart Intrepid when powered by a DC-DC power supply is 20 V/m, as stated in the CISPR 25 standard for the frequency range of 80 MHz to 2.7 GHz. This limit applies only during defibrillation.',
#   'score': '4',
#   'feedback': 'The response provided is mostly correct, accurate, and factual. It correctly identifies the limit level for the radiated RF electromagnetic field as 20 V/m and specifies the frequency range of 80 MHz to 2.7 GHz, which aligns with the reference answer. However, the response includes additional information about the CISPR 25 standard and the condition that the limit applies only during defibrillation, which is not mentioned in the reference answer. This additional information is not necessarily incorrect, but it is not required to answer the question as posed. Therefore, the response is not completely correct based on the reference answer but is mostly correct.'}]
